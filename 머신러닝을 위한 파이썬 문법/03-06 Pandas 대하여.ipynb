# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(0)

# %%
df = pd.DataFrame(np.random.randint(60,101, size=(10,4)), columns=['Kor', 'Eng', 'Math','Sci'])

# %%
df
# Out:
#    Kor  Eng  Math  Sci
# 0   60   63    63   99
# 1   69   79    81   96
# 2   83   66    84   84
# 3   72   61    98   99
# 4   83   84    77   97
# 5   85   73    68   69
# 6   80   76    65   75
# 7   60   78    95   84
# 8   89   79    79   74
# 9   99   92    61   69

# %%
print(dir(df))
# Out:
# ['Eng', 'Kor', 'Math', 'Sci', 'T', '_AXIS_LEN', '_AXIS_NAMES', '_AXIS_NUMBERS', '_AXIS_ORDERS', '_AXIS_REVERSED', '_AXIS_TO_AXIS_NUMBER', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_wrap__', '__bool__', '__class__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__div__', '__doc__', '__eq__', '__finalize__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmatmul__',
# ...

# %%
df.Eng
# Out:
# 0    63
# 1    79
# 2    66
# 3    61
# 4    84
# 5    73
# 6    76
# 7    78
# 8    79
# 9    92
# Name: Eng, dtype: int32

# %%
df.Sci
# Out:
# 0    99
# 1    96
# 2    84
# 3    99
# 4    97
# 5    69
# 6    75
# 7    84
# 8    74
# 9    69
# Name: Sci, dtype: int32

# %%
df.Kor
# Out:
# 0    60
# 1    69
# 2    83
# 3    72
# 4    83
# 5    85
# 6    80
# 7    60
# 8    89
# 9    99
# Name: Kor, dtype: int32

# %%
#컬럼 추가하기 추가할때 주의할 것은 예약어인지 확인해보기 dir사용
df['합계'] = df.Kor + df.Eng + df.Math + df.Sci

# %%
df.합계
# Out:
# 0    285
# 1    325
# 2    317
# 3    330
# 4    341
# 5    295
# 6    296
# 7    317
# 8    321
# 9    321
# Name: 합계, dtype: int32

# %%
df
# Out:
#    Kor  Eng  Math  Sci  sum   합계
# 0   60   63    63   99  285  285
# 1   69   79    81   96  325  325
# 2   83   66    84   84  317  317
# 3   72   61    98   99  330  330
# 4   83   84    77   97  341  341
# 5   85   73    68   69  295  295
# 6   80   76    65   75  296  296
# 7   60   78    95   84  317  317
# 8   89   79    79   74  321  321
# 9   99   92    61   69  321  321

# %%
#예약어로 걸린것들을 사용하면 안됨
#ex) sum

# %%
print(dir(df))
# Out:
# ['Eng', 'Kor', 'Math', 'Sci', 'T', '_AXIS_LEN', '_AXIS_NAMES', '_AXIS_NUMBERS', '_AXIS_ORDERS', '_AXIS_REVERSED', '_AXIS_TO_AXIS_NUMBER', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_wrap__', '__bool__', '__class__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__div__', '__doc__', '__eq__', '__finalize__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmatmul__',
# ...

# %%
df['average'] = (df.Kor + df.Eng + df.Math + df.Sci) / 4
# or df.합계 / 4

# %%
df
# Out:
#    Kor  Eng  Math  Sci  sum   합계  average
# 0   60   63    63   99  285  285    71.25
# 1   69   79    81   96  325  325    81.25
# 2   83   66    84   84  317  317    79.25
# 3   72   61    98   99  330  330    82.50
# 4   83   84    77   97  341  341    85.25
# 5   85   73    68   69  295  295    73.75
# 6   80   76    65   75  296  296    74.00
# 7   60   78    95   84  317  317    79.25
# 8   89   79    79   74  321  321    80.25
# 9   99   92    61   69  321  321    80.25

# %%
df.average
# Out:
# 0    71.25
# 1    81.25
# 2    79.25
# 3    82.50
# 4    85.25
# 5    73.75
# 6    74.00
# 7    79.25
# 8    80.25
# 9    80.25
# Name: average, dtype: float64

# %%
df['석차'] = df['합계'].rank(method='min', ascending=False)

# %%
df
# Out:
#    Kor  Eng  Math  Sci  sum   합계  average    석차
# 0   60   63    63   99  285  285    71.25  10.0
# 1   69   79    81   96  325  325    81.25   3.0
# 2   83   66    84   84  317  317    79.25   6.0
# 3   72   61    98   99  330  330    82.50   2.0
# 4   83   84    77   97  341  341    85.25   1.0
# 5   85   73    68   69  295  295    73.75   9.0
# 6   80   76    65   75  296  296    74.00   8.0
# 7   60   78    95   84  317  317    79.25   6.0
# 8   89   79    79   74  321  321    80.25   4.0
# 9   99   92    61   69  321  321    80.25   4.0

# %%
#컬럼 지우기
#첫번째 방법
df.drop(columns='합계', axis=0, inplace=True)
#두번째 방법
#df = df.drop(columns='합계', axis=0)

# %%
df
# Out:
#    Kor  Eng  Math  Sci  sum  average    석차
# 0   60   63    63   99  285    71.25  10.0
# 1   69   79    81   96  325    81.25   3.0
# 2   83   66    84   84  317    79.25   6.0
# 3   72   61    98   99  330    82.50   2.0
# 4   83   84    77   97  341    85.25   1.0
# 5   85   73    68   69  295    73.75   9.0
# 6   80   76    65   75  296    74.00   8.0
# 7   60   78    95   84  317    79.25   6.0
# 8   89   79    79   74  321    80.25   4.0
# 9   99   92    61   69  321    80.25   4.0

# %%
df.drop(columns='sum', axis=0, inplace=True)

# %%
df
# Out:
#    Kor  Eng  Math  Sci  average    석차
# 0   60   63    63   99    71.25  10.0
# 1   69   79    81   96    81.25   3.0
# 2   83   66    84   84    79.25   6.0
# 3   72   61    98   99    82.50   2.0
# 4   83   84    77   97    85.25   1.0
# 5   85   73    68   69    73.75   9.0
# 6   80   76    65   75    74.00   8.0
# 7   60   78    95   84    79.25   6.0
# 8   89   79    79   74    80.25   4.0
# 9   99   92    61   69    80.25   4.0

# %%
df = df.drop(columns='average', axis=0)

# %%
df
# Out:
#    Kor  Eng  Math  Sci    석차
# 0   60   63    63   99  10.0
# 1   69   79    81   96   3.0
# 2   83   66    84   84   6.0
# 3   72   61    98   99   2.0
# 4   83   84    77   97   1.0
# 5   85   73    68   69   9.0
# 6   80   76    65   75   8.0
# 7   60   78    95   84   6.0
# 8   89   79    79   74   4.0
# 9   99   92    61   69   4.0

# %%
df = df.drop(columns=['Kor','Eng','Math'], axis=0)

# %%
df
# Out:
#    Sci    석차
# 0   99  10.0
# 1   96   3.0
# 2   84   6.0
# 3   99   2.0
# 4   97   1.0
# 5   69   9.0
# 6   75   8.0
# 7   84   6.0
# 8   74   4.0
# 9   69   4.0

# %%
#인덱스 변경
df.index =['김경태','오호정','윤현영','박성호','김현진','한수란','박하람','이요한','이동원','안길환']

# %%
df
# Out:
#      Sci    석차
# 김경태   99  10.0
# 오호정   96   3.0
# 윤현영   84   6.0
# 박성호   99   2.0
# 김현진   97   1.0
# 한수란   69   9.0
# 박하람   75   8.0
# 이요한   84   6.0
# 이동원   74   4.0
# 안길환   69   4.0

# %%
#마인드맵 사용해서 자신이 할 수 있는 기술스택만들기
